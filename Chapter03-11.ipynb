# %% [markdown]
# ##시퀀스 자료형
# * 문자열 :
# * 시퀀스형에서 사용할수 있는 메소드(count(). index(), split() 등...)
# * 슬라이싱 ( [:] [: :])
# * 요소들로 이루어져 가능했던 기능들 (요소 합치기, 요소 찾기 등등)
# *
# list：
# * 시퀀스형에서 사용할수 있는 메소드(count(), index(), split() 등...)
# * 슬라이싱 ( [:] [: :])
# * 요소들로 이루어져 가능했던 기능들 (요소 합치기, 요소 찾기 등등)
# * list 지원하는 다양한 메소드(append(). insert(). del, sort(), reverse
# ()]
#
# *tuple :
# * 리스트처럼 요소를 일렬로 저장하지만 안에 저장된 요소를 변경, 추가.
# 삭제할 수 없다.
# * 값을 추가, 삭제, 변경할 수 없기 때문에. 사용하지 못하는 메소드가 많다
# * tuple의 생성 방법은 tuple = 값, 값 또는 tuple = (값, 값)
# * 그리고 엄청난 비일이 숨겨져있어요
# * 튜플은 소괄호입니다.

# %%
 # 리스트 대괄호 [], 튜플은 소괄호 ()
튜플= (1, "이", 3.0)
print (type(튜플))
print(튜플)
# 리스트 = [1, "이", 3.0]
# pr int(type(리스트))
# print(리스트)
튜플2 = 1, "이", 3
print (type(튜플2))
print(튜플2)
# Out:
# <class 'tuple'>
# (1, '이', 3.0)
# <class 'tuple'>
# (1, '이', 3)

# %%
#하나의 값만 들어있는 튜플만 만들고 싶다면?
튜플_솔로 = (1, )
pr int (type(튜플_솔로))
pr int (튜플_솔로)
튜플_나는솔로 = (1)
pr int (type(튜플_ 나는솔로))
print(튜플_나는솔로)

# 값 추가, 삭제, 변경 불가.
pr int(튜플)
pr int(dir(튜플))
print (dir(list))
진실일까?

* 값 추가. 삭제. 변경 불가.
print (튜플)
print (dir(튜플))
튜플_리스트화 = 1ist (튜플)
pr int ( type(튜플_리스트화))
진실일까?

# %%
#정말로 값의 삽입, 삭제, 변경을 지원하지 않는지 확인
#튜플.append("두리안")
# del 튜플[2]
튜플[1] ="너만 믿는다"
튜플

# %%
#번외
수강생= "중꺽그마"
수강생_list = list(수강생)
수강생_tuple = tuple(수강생)
print(수강생_list)
print(수강생_tuple)
수강생_list [1] =""
# Out:
# ['중', '꺽', '그', '마']
# ('중', '꺽', '그', '마')

# %%
수강생= "중꺾그마"
수강생_list = list(수강생)
수강생_tuple = tuple(수강생)
print(수강생_list)
print(수강생_tuple)
수강생_list [1] = "뿌"
print(수강생_list)
#ioin함수 공부 알고 있으면 코테에 좋아요
취뽀_수강생="".join(수강생_list)
print(취뽀_수강생)
# Out:
# ['중', '꺾', '그', '마']
# ('중', '꺾', '그', '마')
# ['중', '뿌', '그', '마']
# 중뿌그마

# %%
# 공통점 뭔가요?
pr int(튜플)
#길이를 구할 수 있아요
len(튜플)
#곱하기 연산으로 요소를 복사할 수 있어요
튜플 * 3

# 공통점 뭔가요?
print (튜플)
#길이를 구할 수 있아요
len(튜플)
#곱하기 연산으로 요소를 복사할 수 있어요
튜플 * 3
#튜플은 요소들끼리 더할 수 있다
튜플•+ 튜플

# 공통점 뭔가요?
print(튜플)
#길이를 구할 수 있아요
len(튜플)
#곱하기 연산으로 요소를 복사할 수 있어요
튜플* 3
#튜플은 요소들끼리 더할 수 있다
튜플 + 튜플
#튜플은 인덱싱이 가능하다
튜플[2]
#튜플의 인덱스
튜플. index(3.0)
#튜플 요소의 개수
튜플. count (1)
#튜플도 슬라이싱이 가능하다
튜플 [1:3]

# %% [markdown]
# #tuple 왜 쓸까요?
# (여러분은 다른 수강생들 보다 더 돋보이게 만들어줄 수 있어요
# 1.3G0가 불가하기 때문입니다. (넣고, 삭제하고, 바꾸고) 무슨 소리GO
#
# 여러명이 코딩을 하는 경우 변경되면 안되는 변수를 건드리는 경우 또는 값이 변경되면 안되는 중요한 데이터를 넣어서 보안적으로 관리하기 좋다
# 은행 걔좌본호 비밀번호
#
# 2. list는 tuple보다 무겁다
#
# 단지 기능이 많아서 무거운 걸까? 파이선은 c로 만들어졌다 ㄴㄴ
#
# 파이선은 동적배열을 지원
# - list - [1,2,3,4]생성해서 4개에 값을 모두 넣는다
# - 문제는 그아음 값을 추가 이미 공간이 다 찼지대문에 추가 할당을 진행한다
# 추가 한당시 메모리 크기는 4,8,16,24
#
# 3. 리스트는 가변, 튜플은 불변
#     값이 고정되어야 하거나 크기가 작을경우 튜플을 권장한다.

# %% [markdown]
# * 가변객체와, 불변객체(우리 이미 다 써봄... 공부하다가 놀랄 수 있어요)
# * 파이썬 리스트의 동적배열
# * 이왕 이렇게된거 자료구조 책을 한번 사보는것도 추천합니다. ( 파이썬 클린코드)
# • 가변객체와, 불변객체(우리 이미 다 써봄... 공부하다가 놀랄 수 있어요)
# • 파이썬 리스트의 동적배열
# • 이왕 이렇게된거 자료구조 책을 한번 사보는것도 추천합니다. (파이썬 클린코드)
