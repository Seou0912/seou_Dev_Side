# %%
# 입력과 출력
# 입력 : input()
# 출력 : print()
# 함수와 메서드
#> 함수: 어디에 속해있지 않고 단돋 모듚이라 함수를 그냥 호출하여 사용이 가능
#예) print(), input()
#http://docs.python.org/ko/3/library/functions.html
#>메서드 : 함수의 클래스 안에 속해 있고 클래스의 맴버 변수들을 이용해서 구현된것
#예 "까먹으신건가요?".count("까")/ 까가 몇개    index("까")
"까먹으신건가요?".count("까")
"까먹으신건가요?".index("까")
# Out:
# 0

# %%
인사=input()
print(인사+"반갑습니다.")
hii=input("(우리학교최고 )아...안녕)")
print(hii+"눈부시게")
# Out:
# seouJung
# seouJung반갑습니다.
# (우리학교최고 )아...안녕)hi
# hi눈부시게

# %%
#int*), float(), str(),bool()
정수=int(input())
정수= int(정수)
print(정수, type(정수))

실수 = float(input())
print(실수, type(실수))
# Out:
# 5
# 5 <class 'int'>
# 5.4
# 5.4 <class 'float'>

# %% [markdown]
# 그 외 입력갑의 형변화이 가능한 종류
# tuyple()
# list()
# dict()
# set()

# %%
넌센스, 정답 = input()
print(정답)
# Out:
# 앙
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-4955a508686a> in <cell line: 1>()
# ----> 1 넌센스, 정답 = input()
#       2 print(정답)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
넌센스, 정답 = input(). split()
print(f'넌센스 귀즈 : {넌센스}')
print(f'정답 : {정답}')
# Out:
# 스페인에서에스파를 만나면
# 넌센스 귀즈 : 스페인에서에스파를
# 정답 : 만나면

# %%
넌센스, 정답 = input(). split(".")
print(f'넌센스 귀즈 : {넌센스}')
print(f'정답 : {정답}')
# Out:
# 스페인에서 에스파를 만나면?.에스파냐
# 넌센스 귀즈 : 스페인에서 에스파를 만나면?
# 정답 : 에스파냐

# %%
# 시퀀스 자료형에 다 지원되는 메소드
번호1, 번호2, 번호3, 번호4 = input().split(",")
번호1 = int(번호1)
번호2 = int(번호2)
번호3 = int(번호3)
번호4 = int(번호4)
# Out:
# 5.2,6.5,8.5,6.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-64514ffaf315> in <cell line: 3>()
#       1 # 시퀀스 자료형에 다 지원되는 메소드
#       2 번호1, 번호2, 번호3, 번호4 = input().split(",")
# ----> 3 번호2 = int(번호2)
#       4 번호3 = int(번호3)
#       5 번호4 = int(번호4)
#
# ValueError: invalid literal for int() with base 10: '6.5'

# %%
#map()
번호1, 번호2, 번호3, 번호4 = map(int, input().split(","))
print(type(번호1),번호2,번호3,번호4)
# Out:
# 5.2,6.2,5,5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-6e4f4a2f3e10> in <cell line: 2>()
#       1 #map()
# ----> 2 번호1, 번호2, 번호3, 번호4 = map(int, input().split(","))
#       3 print(type(번호1),번호2,번호3,번호4)
#
# ValueError: invalid literal for int() with base 10: '5.2'

# %%
#레거시 : 누군가 남겨두고간 코드
#리팩토링: 결과의 변경 없이 코드의 구조를 재조정하는 것

#fish__r, fish__s, fish__j = "붕어빵(팥)", "붕어빵(슈크림)", "붕어빵(잡채)"
fish__r, fish__s, fish__j =input('붕어빵(팥), 붕어빵(슈크림), 붕어빵(잡채)를 순서대로 개수를 입력하고 꼭 쉼표를 입력하세요 안사면 공백').split(',')
fish__r_pay, fish__s__pay, fish__j__pay = 2000, 2500, 3000
order_s, order_j = 2, 3

order_s__pay, order_j__pay = fish__s__pay * order_s, fish__j__pay * order_j
sum = order_s + order_j
sum_pay = order_s__pay + order_j__pay

print(f'주문이 완료되었습니다. {fish__s} {order_s}개, {fish__j} {order_j}개, 총{sum} 개 결재금액은 {sum_pay} 입니다.')
# Out:
# 붕어빵(팥), 붕어빵(슈크림), 붕어빵(잡채)를 순서대로 개수를 입력하고 꼭 쉼표를 입력하세요 안사면 공백0 슈크림 잡채
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-7e38366058d3> in <cell line: 5>()
#       3
#       4 #fish__r, fish__s, fish__j = "붕어빵(팥)", "붕어빵(슈크림)", "붕어빵(잡채)"
# ----> 5 fish__r, fish__s, fish__j =input('붕어빵(팥), 붕어빵(슈크림), 붕어빵(잡채)를 순서대로 개수를 입력하고 꼭 쉼표를 입력하세요 안사면 공백').split(',')
#       6 fish__r_pay, fish__s__pay, fish__j__pay = 2000, 2500, 3000
#       7 order_s, order_j = 2, 3
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
#print() 함수에 기능을 이용
print("쵸코칩","민트","샷추가","휘핑크림")
print("쵸코칩","민트","샷추가","휘핑크림", sep='/')
print("쵸코칩","민트","샷추가","휘핑크림", sep=':')
print("쵸코칩","민트","샷추가","휘핑크림", sep= '\n')
# Out:
# 쵸코칩 민트 샷추가 휘핑크림
# 쵸코칩/민트/샷추가/휘핑크림
# 쵸코칩:민트:샷추가:휘핑크림
# 쵸코칩
# 민트
# 샷추가
# 휘핑크림

# %%
#end
print("쵸코칩","민트","샷추가","휘핑크림", end= (' '))
print("쵸코칩","민트","샷추가","휘핑크림", end= (' '))
print("쵸코칩","민트","샷추가","휘핑크림", end= (' '))
print("쵸코칩","민트","샷추가","휘핑크림", end= (' '))
# Out:
# 쵸코칩 민트 샷추가 휘핑크림 쵸코칩 민트 샷추가 휘핑크림 쵸코칩 민트 샷추가 휘핑크림 쵸코칩 민트 샷추가 휘핑크림
