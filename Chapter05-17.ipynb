# %%
def 양파() :
    print("양파를 2개를 수확했습니다.")
def 대파() :
    print("대파를 수확했습니다.")
# 함수 호출하기
양파 ()
대파()



def 수확() :
    print('올해 비가 많이 왔습니다.')
    print ('농작을 수확량이 현저히 줄었습니다. ')
수확()
# Out:
# 양파를 2개를 수확했습니다.
# 대파를 수확했습니다.
# 올해 비가 많이 왔습니다.
# 농작을 수확량이 현저히 줄었습니다.

# %%
def 수학():
        print('고라니 2마리')
    수학()

# %%
def function(x,y):
    z=x+y
    print(z)

    #A등급 10마리 B등급 9마리
    print('옥수수와 수박의 수활량:', function(10,2))

# %%
def count(pri, co):
    return pri * co
print (count(1000,5), '원입니다.')
# Out:
# 5000 원입니다.

# %%
won= {'1emdrmq':1000,'2emdrmq':500, '3emdrmq',100}

def count(a, b, c):
    합계 = won['1emdrmq']* a + won['2emdrmq'] *b won['3emqrma']
    return 합계
print (count(5,2,3), '원입니다.')

# %%
def oz():
    x = float(input("첫 번째 수를 입력하세요: "))
    y = float(input("두 번째 수를 입력하세요: "))
    return x * y

result = oz()
print(result)
# Out:
# 첫 번째 수를 입력하세요: 2
# 두 번째 수를 입력하세요: 5
# 10.0

# %%
print("A")

def message() :
    print("B")

print("C")

message()
# Out:
# A
# C
# B

# %%
def make_url():
    print("google")
    url = "www." + make_url() + ".com"
    return url

# %%
def make_url(input_str):
    url = "www." + input_str + ".com"
    return url

print(make_url("google"))
# Out:
# www.google.com

# %%
def 함수0(num) :
    return num * 2

def 함수1(num) :
    return 함수0(num + 2)

def 함수2(num) :
    num = num + 10
    return 함수1(num)

c = 함수2(2)
print(c)
# Out:
# 28

# %%
numbers = [5, 8, 1, 0, 6, 9]
missing_sum = 0

for i in range(10):
    if i not in numbers:
        missing_sum += i

print(missing_sum)
# Out:
# 16

# %%
class MyClass:
    def __init__(self, arg1, arg2):
        self.arg1 = arg1
        self.arg2 = arg2
        # 초기화 작업을 수행하는 코드들...

# MyClass 클래스의 인스턴스를 생성할 때 자동으로 __init__ 메서드가 호출됩니다.
my_instance = MyClass(value1, value2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-799da2f65af3> in <cell line: 8>()
#       6
#       7 # MyClass 클래스의 인스턴스를 생성할 때 자동으로 __init__ 메서드가 호출됩니다.
# ----> 8 my_instance = MyClass(value1, value2)
#
# NameError: name 'value1' is not defined
